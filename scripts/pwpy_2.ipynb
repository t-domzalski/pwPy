# %% [markdown]
# # Skrypt z zajęć 10/03/2026

# %%
2 + 2
# Out:
# 4

# %%
"hello"
# Out:
# 'hello'

# %%
2 + 2
3 + 3
# Out:
# 6

# %%
print(2 + 2)
# Out:
# 4

# %%
print(2 + 2)
3 + 3
# Out:
# 4
# 6

# %%
print(2 + 2)
(3 + 3)
print(4 + 4)
# Out:
# 4
# 8

# %%
print(2 + 2)
print(3 + 3)
print(4 + 4)
# Out:
# 4
# 6
# 8

# %% [markdown]
# # Tworzenie zmiennych

# %%
2
# Out:
# 2

# %%
a = 2

# %%
a
# Out:
# 2

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = 12323523
a
# Out:
# 12323523

# %%
type(a)
# Out:
# int

# %%
pi = 3.14

# %%
type(pi)
# Out:
# float

# %%
print("hello")
# Out:
# hello

# %%
slowo = "hello"

# %%
type(slowo)
# Out:
# str

# %%
bl = True

# %%
type(bl)
# Out:
# bool

# %%
x = None
type(x)
# Out:
# NoneType

# %% [markdown]
# Zasady budowania nazw zmiennych

# %%
def = 5
# Out:
#   File "/tmp/ipykernel_454/3093416914.py", line 1
#     def = 5
#         ^
# SyntaxError: invalid syntax

# %%
bla2 = 5

# %%
2bla = 5
# Out:
#   File "/tmp/ipykernel_454/2256020983.py", line 1
#     2bla = 5
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Obiekty i referencje do pamięci

# %%
x = 5

# %%
y = x + 5

# %%
y
# Out:
# 10

# %%
id(x)
# Out:
# 11654504

# %%
y = x

# %%
id(y)
# Out:
# 11654504

# %%
x = 20

# %%
print(id(x))
id(y)
# Out:
# 11654984
# 11654504

# %% [markdown]
# Task1. Utwórz cztery zmienne:
#
# - `imie`
# - `wiek`
# - `wzrost`
# - `is_student`
#
# Przypisz im odpowiednie wartości (np. imię jako str, wiek jako int, wzrost jako float, a informację czy ktoś jest studentem jako boolean).
#
# Następnie sprawdź **jakiego typu jest każda z tych zmiennych**, używając funkcji `type()`.
#
# Wyświetl typ każdej zmiennej w notebooku.

# %%
wiek = 5
wzrost = 1.81
imie = "Borys"
is_student = True

# %%
print(type(wiek))
print(type(wzrost))
print(type(imie))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
tp = [wiek,
wzrost,
imie,
is_student]

# %%
tp
# Out:
# [5, 1.81, 'Borys', True]

# %%
type(tp)
# Out:
# list

# %% [markdown]
# # Proste operacje matematyczne i konwersje prymitywnych typów zmiennych

# %%
a = 10
b = 5

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# 5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 2.0

# %%
a ** b
# Out:
# 100000

# %%
dzielenie = a / b

# %%
dzielenie
type(dzielenie)
# Out:
# float

# %%
int(dzielenie)
# Out:
# 2

# %%
# konwersje mają swoje ograniczenia

# %%
int(2.57)
# Out:
# 2

# %%
str(3)
# Out:
# '3'

# %%
int("bla")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_163/2005927359.py in <cell line: 0>()
# ----> 1 int("bla")
#
# ValueError: invalid literal for int() with base 10: 'bla'

# %% [markdown]
# Task2. Podstawa trójkąta wynosi 5, a wysokość 8.
#
# 1. Przypisz te wartości do zmiennych `a` (podstawa) oraz `h` (wysokość).
# 2. Oblicz pole trójkąta i zapisz wynik w zmiennej `pole`.
# 3. Wyświetl wynik.

# %%
a = 5
h = 8

# %%
pole = a * h / 2

# %%
pole
# Out:
# 20.0

# %% [markdown]
# a_2 to nowa dlugosc podstawy

# %%
a_2 = a + 4

# %%
# Python bierze pod uwagę kolejność działań
pole_2 = a_2 * h / 2

# %%
pole_2
# Out:
# 36.0

# %% [markdown]
# Task3. Kalkulator całkowitej wartości zakupu.
#
# 1. Utwórz zmienne:
#    - `cena = 12.5`
#    - `ilosc = 4`
#
# 2. Oblicz całkowitą wartość zakupu i zapisz ją w zmiennej `suma`.
#
# 3. Wyświetl komunikat w postaci:
#
# Calkowita wartosc to (wynik waszych kalkulacji)

# %%
"abc" + "def"
# Out:
# 'abcdef'

# %%
cena = 12.5
ilosc = 4
suma = cena * ilosc
print("Calkowita wartosc to", suma)
# Out:
# Calkowita wartosc to 50.0

# %%
print(f"Calkowita wartosc to: {suma}")
# Out:
# Calkowita wartosc to: 50.0

# %%
wiadomosc = "Calkowita wartosc to" + suma
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_454/3364428777.py in <cell line: 0>()
# ----> 1 wiadomosc = "Calkowita wartosc to" + suma
#
# TypeError: can only concatenate str (not "float") to str

# %%
wiadomosc = "Calkowita wartosc to " + str(suma)

# %%
wiadomosc
# Out:
# 'Calkowita wartosc to 50.0'

# %% [markdown]
# # Operatory porownan i operatory boolean

# %%
a = 5
b = 10

# %%
a == 5
# Out:
# True

# %%
a == 4
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != 5
# Out:
# False

# %%
a != 4
# Out:
# True

# %%
b > a
# Out:
# True

# %%
a < b
# Out:
# True

# %%
c = 5

# %%
a <= b
# Out:
# True

# %%
a <= c
# Out:
# True

# %%
# Operatory boolean
# and
# or
# not

# %%
a
# Out:
# 10

# %%
b
# a
# Out:
# 5

# %%
a == 5 and b == 5
# Out:
# False

# %%
a == 10 and b == 5
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and True and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# Task4. Czy dana osoba może wejść na koncert.
#
# Utwórz dwie zmienne:
# - `wiek = 22`
# - `is_ticket = True`
#
# Osoba może wejść na koncert, jeśli:
# - ma co najmniej 18 lat
# - posiada bilet.
#
# 1. Zapisz wynik sprawdzenia w zmiennej `wstep`.
# 2. Wyświetl wynik programu (`True` lub `False`).

# %%
wiek = 22
is_ticket = True

wstep = wiek >= 18 and is_ticket

# %%
print(wstep)
# Out:
# True
